# %% [markdown]
# # Table of contents<a name="top"></a>
#
# 1. [Classical models](#1)
#
#     1.1 [Atomic Theories](#1.1)
#
#     1.2 [Wave Nature of Matter](#1.2)
#
#     1.3 [Particulate Nature of Matter](#1.3)
#     <br/>
#     <br/>
#
# 2. [Quantum Mechanics](#2)
#
#     2.1 [De Broglie's Wavelength](#2.1)
#
#     2.2 [Heisenberg Uncertainty Principle](#2.2)
#
#     2.3 [Schrödinger's Equation](#2.3)
#
#       2.3.1 [Free particle in zero potential](#2.3.1)
#
#       2.3.2 [Free particle in constant potential](#2.3.2)
#
#       2.3.3 [1d Particle in a box](#2.3.3)
#
#     2.4 [Schrödinger's Equation for orbitals](#2.4)
#
#       2.4.1 [s orbitals](#2.4.1)
#
#       2.4.2 [p orbitals](#2.4.2)
#
#       2.4.3 [d orbitals](#2.4.3)
#     <br/>
#     <br/>
# 3. [Electronic transitions](#3)
# 4. [Photoelectron spectroscopy](#4)
# 5. [Molecular Orbital Theory](#5)
# 6. [Band Theory](#6)
# 7. [Transition Elements](#7)

# %% [markdown]
# ## <span style="color:#879cc1">Classical models: old but gold</span> <a name="1"></a>
#
# [go to top](#top)
# #### Dalton's Atomic theory <a name="1.1"></a>
# - Every element is composed of tiny indestructible particles called atoms
# - All atoms of a given element have the same mass and other properties that distinguish them from atoms of other elements
# - Atoms combine in whole number ratios to form compounds
#
# #### Rutherford-Bohr Atomic Model
# - electrons orbit the nucleus in an atom
# - used to explain emission spectra
# - orbits are quantized
# - impossible for electron to exist between orbits
#
# ##### Failure of this model
# - violates conservation of energy
#     - electrons are accelerated along the orbit $\Rightarrow$ electron should continuously lose energy
#     - electron will spiral into the nucleus $\Rightarrow$ atom would collapse
# - predicted hydrogen emmision spectra but not the other elements

# %% [markdown]
# ### Wave nature of matter <a name="1.2"></a>
#
# [go to top](#top)

# %% [markdown]
# #### Waves ####
# All waves can be described by the following form
#
# $$\frac{\partial^{2}u}{\partial {t^{2}}} = C^{2}\frac{\partial^{2} u}{\partial x^{2}}$$
#
# where *u* is the displacement vector, *t* is time, *x* is position and C is a constant
#
# <img src="http://slideplayer.com/slide/5287993/17/images/10/Electromagnetic+Spectrum.jpg" style= "height: 300px;" "width: 300px;" />

# %% [markdown]
# #### Young's Double Slit ####
#
# Recap : $d \sin\theta = n\lambda$
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Double-slit.svg/1200px-Double-slit.svg.png" style= "height: 300px;" "width: 300px;" />
#
# - interference similar to that observed for light is recorded when electrons are sent through a double slit
# - opposite of what one would expect for particles

# %% [markdown]
# ### Particulate nature of matter <a name="1.3"></a>
#
#
# [go to top](#top)

# %% [markdown]
# #### Atomic Spectra ####
# - Atoms of every element have a unique absorption/emission characteristic
# - Only specific transitions equivalent to the difference in discrete energy levels of the atoms are permissible

# %% [markdown]
# #### Blackbody Radiation####
#
# - Hot objects emits electromagnetic radiation which shifts towards shorter wavelengths as temperature increases
# - An ideal blackbody absorbs and emits all radiation incident on it, regardless of frequency
#     - eg. cavity with a small hole
#
# ##### Rayleigh-Jeans Law #####
# - all oscillators share equally in energy supplied by walls
# - predicts that even ccol objects should radiate in visible and UV regions
# - NO darkness
#
# $$B_{\lambda} = \frac{2ck_{B}T}{\lambda^{4}}$$
#
# Where $B_{\lambda}$ is the spectral radiance, $k_B$ is the boltzmann constant, and temperature is in Kelvins
#
# - We see that the energy intensity is asymptopic as $\lambda$ approaches zero. This failure in the model is described as the *ultraviolet catastrophe*

# %% [markdown]
# ![alt text](http://farm4.static.flickr.com/3612/3346470005_543a193584.jpg)

# %% [markdown]
# ##### Planck's Law #####
# $$B_{\lambda} = \frac{2hc}{\lambda^{5}}\frac{1}{\mathrm{e}^{\frac{hc}{\lambda k_{B} T}}-1}$$
#
# - Avoids the ultraviolet catastrophe by quantizing the electromagnetic energy emiited
#
# - reduces to Rayleigh-Jeans Law at higher wavelengths

# %% [markdown]
#  #### Photoelectric Effect ####
#
# - Is the ejection of electrons from the surface of a metal when light of sufficient energy is incident of it
#
# ##### Failure of Classical Model #####
# ###### Predictions######
# - If the intensity of the light is increased, electrons of higher energy should be ejected
# - If $\lambda$ is shorter more electrons should be ejected
#
# ###### Observations######
# - Below threshold frequency, no electrons are ejected no matter the intensity
# - Above threshold frequency, energy of ejected electrons is linearly dependent on light frequency and independent of intensity
# - At low intensities, electrons are immediately ejected when light above threshold frequency is incident on the metal
#
# ##### Explaining the photoelectric effect #####
# - light consists of quanta called photons, where $E = h\nu$
# - only when photon has sufficient energy then an electron will be ejected from the metal
#
# $$E_{max} = h\nu - \Phi = \frac{1}{2}mv^2$$
#
# where $E_{max}$ is the maximum KE of the ejected electron, $\Phi$ is the work function(ie binding energy of the electron to the nucleus)

# %% [markdown]
# #### Compton Scattering####

# %% [markdown]
# ![alt text](https://sites.google.com/site/puenggphysics/_/rsrc/1500628128421/home/unit-iv/compton-effect/Picture1.jpg)

# %% [markdown]
# - the wavelength of the scattered photon is shifted by a value which is related to $\phi$

# %% [markdown]
# ## <span style="color:#879cc1">Quantum Mechanics: A better theory of nature</span> <a name="2"></a>
#
#
# [go to top](#top)

# %% [markdown]
# #### De Broglie's relation: <a name="2.1"></a>
# $$\lambda = \frac{h}{\vec{p}}$$
# where $h = 6.626 \times 10^{-34} \mathrm{J \ s} $
#
# De Broglie's relation links the wavelength of a particle to its momentum. Under classical relativity, this relation can be expressed as:
# $$\lambda=\frac{h}{mv}$$

# %% [markdown]
# #### Heisenberg's Uncertainty Principle <a name="2.2"></a>
# $$\Delta \vec{x} \Delta \vec{p} \geq \frac{\hbar}{2}$$
# where $\hbar = \frac{h}{2\pi}$
#
# The Heisenberg Uncertainty Principle sets a fundamental limit on the precision at which we can determine pairs of complementary properties of a particle

# %% [markdown]
# #### Orbitals ####
# - Probability distribution map of a region where a electron is likely to be found
# - Size, shape and orientation in spacce is described by 3 integer term in the wave function
#     - $n$: principal quantum number
#     - $l$: angular momentum quantum number
#     - $m_{l}$: magnetic quantum number
#
#
# - $m_{s} \rightarrow$ describe magnetic property of electron (not from wavefunction)
#     - $m_{s} = \frac{1}{2}\rightarrow$ spin up
#     - $m_{s} = -\frac{1}{2}\rightarrow$ spin down
#
#
# - each set of $n$,$l$ and $m_i$ identifies a specific quantum state of the atom
#
# - the restrictions on $l$ and $m_i$ give rise to $n^2$ sets of quantum numbers for every value of n
#
# - when $n>1$, the $n^2$ states correspond to the single energy level $E_n$(same energy).
#     - These states are said to be **degenerate**

# %% [markdown]
# ### Schrödinger's Equation $\Psi(x,t)$ <a name="2.3"></a>
#
# [go to top](#top)
#
# - $\psi$ has no physical interpretation
# - Regions in space where wavefunction goes through zero as it changes sign are called nodes
# - Infinite number of solutions
# - Acceptable wavefunctions must satisfy the boundary and initial conditions
#
# #### Time independent####
#
# $$-\frac{\hbar^{2}}{2m}\frac{d^{2}\psi (x)}{d x^{2}}+V(x)\psi(x) = E\psi(x)$$
#
# - $V(x)$ is the potential energy of the system
# - $E(x)$ is the total energy of the particle
#
#
# - $\frac{\hbar^{2}d^{2}\psi (x)}{d x^{2}}$ is $\vec{p} \ ^{2}$ of the particle $\Rightarrow \frac{\hbar^{2}}{2m}\frac{d^{2}\psi (x)}{d x^{2}}$ is the kinetic energy of the particle
#
#
# ##### Probability Density function #####
# The probability density function of a wavefunction is defined as
#
# $$P(x) = \int_{\infty}^{\infty} \mid {\psi^{2}(x)} \mid dx = \int_{\infty}^{\infty} \psi(x) \ \psi^{*}(x) \ dx =1 \ \mathrm{(normalized)}$$
#
# - For 10.011 all you need to know is the probability of finding a particle at any region in space is given by $p(x)\propto \ \mid \psi^{2}(x) \mid$

# %% [markdown]
# #### Free particle in zero potential <a name="2.3.1"></a>
#
# [go to top](#top)
#
# $\because V=0 \Rightarrow$ initial condition: 0 potential,
#
# $$ \frac{\hbar^{2}}{2m}\frac{d^{2}\psi (x)}{dx^{2}} \ + \ E\psi (x) = 0$$
#
# Solving the differential equation:
#
#
# $$\psi(x) = Ae^{ikx} + Be^{-ikx} = C \cos kx + iD \sin kx$$
#
#
# where $k=\frac{2\pi\sqrt{2mE}}{h} =\frac{\sqrt{2mE}}{\hbar}$
#
# - Energy $E=\frac{\hbar^{2}k^{2}}{2m}$
#
# - therefore the particle has kinetic energy only

# %% [markdown]
# #### Free particle in constant, non zero potential<a name="2.3.2"></a>
#
# [go to top](#top)
#
# $\because V(x)$ is constant, let $V(x)=V$ and thus
#
#
# $$-\frac{\hbar^{2}}{2m}\frac{d^{2}\psi (x)}{d x^{2}}+V\psi(x) = E\psi(x)$$
#
# Solving,
#
# $$\psi(x) = Ae^{ikx} + Be^{-ikx} = C \cos kx + iD \sin kx$$
#
#
# where $k=\frac{\sqrt{2m(E-V)}}{\hbar}$
#
# - Energy $E-V=\frac{\hbar^{2}k^{2}}{2m}$
#
# - $V\uparrow, (E-V)\downarrow, \lambda \uparrow$

# %% [markdown]
# #### 1D Particle in a box <a name="2.3.3"></a>
#
# [go to top](#top)
#
# ##### Infinite potential well
#
#
# <img src="http://www.nyu.edu/classes/tuckerman/adv.chem/lectures/lecture_6/img53.png" style= "height: 300px;" "width: 300px;" />
#
#
# $\psi = 0$ when $x\le 0$ and $x \ge a$ since the particle cannot be outside of the box.
#
# $$ \frac{\hbar^{2}}{2m}\frac{d^{2}\psi (x)}{dx^{2}} \ + \ E\psi (x) = 0$$
#
# Solving,
#
# $$\psi(x) = Ae^{ikx} + Be^{-ikx} = C \cos kx + iD \sin kx$$
#
# where $k = =\frac{\sqrt{2mE}}{\hbar}$
#
# Applying boundary conditions,
# 1. $\psi = 0$ at $x=0$
#     - $\psi(x) = Ae^{ikx_{0}} + Be^{-ikx_{0}} = 0 $
#     - $A=-B$
#
#    $$\psi (x) = A(e^{ikx}-e^{-ikx})=2iA\sin kx$$
#   <br/>
#   <br/>
# 2. $\psi (x) = 0$ at $x = a$
#     - $\psi (x=a) = 2iA\sin ka = 0$
#
#    $$\therefore \ k = \frac{n\pi}{a}, \ \mathrm{where} \ $n = 1,2,3...$$
#
#
# - Energy $E_{n} = \hbar \omega = \frac{n^{2}\pi^{2}\hbar^{2}}{2mL^{2}}, \ n \ge 1$
#
#
#
# <img src = "https://upload.wikimedia.org/wikipedia/commons/thumb/8/8f/InfiniteSquareWellAnimation.gif/200px-InfiniteSquareWellAnimation.gif" style = "width:300px;" "height:300px;"/>

# %% [markdown]
# ### Schrödinger's Equation for orbitals $\Psi(r,\theta,\phi)$ <a name="2.4"></a>
#
#
# [go to top](#top)

# %% [markdown]
# ##### Spherical coordinates #####
# $$x = r\cos\theta\sin\phi$$
# $$y = r\sin\theta\sin\phi$$
# $$z = r\cos\phi$$
#
# ###### Angular momentum, L######
# $$L = \sqrt{l(l+1)}\hbar$$
# $$L^{2} = l(l+1)\hbar^{2}$$
# $$L_{z}=m_{l}\hbar$$

# %% [markdown]
# #### Back to $\Psi$####
# - for each quantum state($n,l,m_l$), there is a unique solution $\Psi_{nlm}$
# - by separation of variables, $\Psi_{nlm}$ can be separated into radial(R) and angular(Y) components
#     - $\Psi(r,\theta,\phi) = R_{nl}(r)\cdot Y_{lm}(\theta, \phi)$
#     <br/>
#     <br/>
#     - $\Psi^{2} \ dV = [R_{nl}]^{2}\cdot[Y_{lm}]^{2}dV = r^{2}[R_{nl}]^{2}\cdot[Y_{lm}]^{2}\sin\theta \ dr \ d\theta \ d\phi$
#
# where $r^{2}[R_{nl}]^{2}$ is the radial probability density function
#
# Location of nodes: $\Psi^2 = 0$ since at nodes probability of electron being there is $0$
#
# - $R(r) = 0$ to determine location of radial nodes
# - $Y_{lm}(\theta,\phi) = 0$ to determine location of angular nodes
#
#  $n =$ $r$ nodes $+$ $l$ nodes $+ 1$

# %% [markdown]
# ### s-orbitals(1 electron atoms)<a name="2.4.1"></a>
#
# [go to top](#top)
#
# - $n > 0$
# - $ l = 0$
# - $m_l =0$
#
#
# - Angular part $Y(\theta,\phi)$
#
#     - $l = 0 \{ Y_{s} = (\frac{1}{4\pi})^{\frac{1}{2}}$
#
#
# - Radial Part $R_{nl}(r)$
#     - $R_{1s} = 2\left(\frac{Z}{a_0}\right)^{\frac{3}{2}}\mathrm{e}^{-\sigma}$
# <br/>
# <br/>
#     - $R_{2s} = \frac{1}{2\sqrt{2}}\left(\frac{Z}{a_0}\right)^{\frac{3}{2}}(2-\sigma) \ \mathrm{e}^{-\frac{\sigma}{2}}$
# <br/>
# <br/>
#     - $R_{3s} = \frac{2}{81\sqrt{3}}\left(\frac{Z}{a_0}\right)^{\frac{3}{2}}(27-18\sigma+2\sigma^{2}) \ \mathrm{e}^{-\frac{\sigma}{3}}$
#
# where $\sigma = \frac{Zr}{a_0}$ and $a_{0} = \frac{\epsilon_{0}h^2}{\pi \ \mathrm{e}^2 m_{e}} = 0.529\times10^{-10} \ \mathrm{m}$

# %%
import matplotlib.pyplot as plt
import numpy as np

a = 0.529*10**(-10)
r = np.linspace(0, 30*a, 100)
s = r/a

y1 = (r*2*(1/a)**(1.5)*np.exp(-s))**2
y2 = (r/(2*np.sqrt(2))*(1/a)**(1.5)*(2-s)*np.exp(-s/2))**2
y3 = (r*2/(81*np.sqrt(3))*(1/a)**(1.5)*(27-18*s+2*s**2)*np.exp(-s/3))**2

fig = plt.figure()
fig_size = plt.rcParams["figure.figsize"]
plt.plot(r, y1, label="1s")
plt.plot(r, y2, label="2s")
plt.plot(r, y3, label="3s")
plt.title("Radial Probability density function of s-orbitals")

plt.xlabel("r")
plt.ylabel("Probability density")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

fig_size[0] = 4
fig_size[1] = 4

plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

#def bohr radius
a = 0.529*10**(-10)

#def x,y,z,r, theta, phi
x = np.linspace(-3*a, 3*a, 100)
y = np.linspace(-3*a, 3*a, 100)

x2,y2 = np.meshgrid(x,y)

r = np.sqrt(x2*x2+y2*y2)

#def sigma
s = r/a

#def psi, psi^2
psi = np.sqrt(1/(4*np.pi))*2*(1/a)**(1.5)*np.exp(-s)
psi2 = (np.sqrt(1/(4*np.pi))*2*(1/a)**(1.5)*np.exp(-s))**2

#plot things
fig = plt.figure()
fig_size = plt.rcParams["figure.figsize"]
ax1 = fig.add_subplot(221)
ax2 = fig.add_subplot(222)
ax3 = fig.add_subplot(223, projection = "3d")

ax1.contour(x2,y2,psi,30)
ax1.title.set_text("1s $\psi$")

ax2.contour(x2,y2,psi2,30)
ax2.title.set_text("1s $\mid \psi \mid^{2}$")

ax3.plot_surface(x2,y2,psi2)
ax3.title.set_text("1s $\mid \psi \mid^{2}$")#i dont know why there is a point at the top of the plot


fig_size[0] = 9
fig_size[1] = 9

plt.show()

# %% [markdown]
# ### p- orbitals (1 electron atoms)<a name="2.4.2"></a>
#
# [go to top](#top)
#
# - $n > 0$
# - $ l = 1$
# - $m_l =-1, \ 0, \ 1$
#
#
# - Angular part $Y(\theta, \phi)$
#     - $Y_{p_{x}} = \left( \frac{3}{4\pi}\right) ^{\frac{1}{2}} \sin\theta\cos\phi$
# <br/>
# <br/>
#     - $Y_{p_{y}} = \left( \frac{3}{4\pi}\right) ^{\frac{1}{2}} \sin\theta\sin\phi$
# <br/>
# <br/>
#     - $Y_{p_{z}} = \left( \frac{3}{4\pi}\right) ^{\frac{1}{2}} \cos\theta$
#
#
# - Radial Part $R_{nl}(r)$
#     - $R_{2_{p}} = \frac{1}{2\sqrt{6}}\left( \frac{Z}{a_0} \right) ^ {\frac{3}{2}} \sigma \ \mathrm{e}^{\frac{-\sigma}{2}}$
# <br/>
# <br/>
#     - $R_{3_{p}} = \frac{4}{81\sqrt{6}}\left( \frac{Z}{a_0} \right) ^ {\frac{3}{2}} (6\sigma - \sigma^2) \ \mathrm{e}^{\frac{-\sigma}{3}}$
#
# where $\sigma = \frac{Zr}{a_0}$ and $a_{0} = \frac{\epsilon_{0}h^2}{\pi \ \mathrm{e}^2 m_{e}} = 0.529\times10^{-10} \ \mathrm{m}$

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

#def bohr radius
a = 0.529*10**(-10)

#def x,y,z,r, theta, phi
x = np.linspace(-20*a, 20*a, 400)
y = np.linspace(-20*a, 20*a, 400)
z = np.linspace(-20*a, 20*a, 400)

x2,y2 = np.meshgrid(x,y)
z2,y3 = np.meshgrid(z,y)

r = np.sqrt(x2*x2+y2*y2)
r2 = np.sqrt(z2*z2+y3*y3)


t = np.arccos(z2/r2)

p = np.arctan2(y2,x2)

#def sigma
s = r/a
s2 = r2/a

#angular component
yP1 = np.sqrt(3/(4*np.pi))*np.cos(p)
yP2 = np.sqrt(3/(4*np.pi))*np.sin(p)
yP3 = np.sqrt(3/(4*np.pi))*np.cos(t)

#radial component
r2p = 1/(2*np.sqrt(6))*(1/a)**(1.5)*s*(np.exp(-s/2))
r2p2 = 1/(2*np.sqrt(6))*(1/a)**(1.5)*s2*(np.exp(-s2/2))
r3p = 4/(81*np.sqrt(6))*(1/a)**(1.5)*(6*s-s**2)*(np.exp(-s/3))

#wavefunction
psi1 = yP1*r2p
psi2 = (yP1*r2p)**2
psi3 = (yP1*r3p)**2
psi4 = (yP2*r2p)**2
psi5 = (yP3*r2p2)**2

#plot things
fig = plt.figure()
fig_size = plt.rcParams["figure.figsize"]
plt.suptitle("Contour maps")

ax1 = fig.add_subplot(231)
ax2 = fig.add_subplot(232)
ax3 = fig.add_subplot(233)
ax4 = fig.add_subplot(234)
ax5 = fig.add_subplot(236)

ax1.contour(x2,y2,psi1, 30)
ax1.title.set_text("$2p_x \ \psi$ on xy plane")


ax2.contour(x2,y2,psi2, 30)
ax2.title.set_text("$2p_x \ \mid \psi \mid^2$ on xy plane")
ax2.annotate("nodal plane yz", xy=(0, 1*10**(-10)), xytext=(0, 3*10**(-10)),
             arrowprops=dict(facecolor='black', shrink=0.05),
            )

ax3.contour(z2,y3,psi5, 30)
ax3.title.set_text("$2p_z \ \mid \psi \mid^2$ on yz plane")
ax3.annotate("nodal plane xy", xy=(1*10**(-10),0), xytext=(3*10**(-10),0),
             arrowprops=dict(facecolor='black', shrink=0.05),
            )

ax4.contour(x2,y2,psi4, 30)
ax4.title.set_text("$2p_y \ \mid \psi \mid^2$ on xy plane")
ax4.annotate("nodal plane xz", xy=(1*10**(-10),0), xytext=(3*10**(-10),0),
             arrowprops=dict(facecolor='black', shrink=0.05),
            )

ax5.contour(x2,y2,psi3, 120)
ax5.title.set_text("$3p_x \ \mid \psi \mid^2$ on xy plane")

fig_size[0] = 15
fig_size[1] = 10


plt.show()

# %% [markdown]
# ### d-orbitals (1 electron atoms)<a name="2.4.3"></a>
#
# [go to top](#top)
#
# - $n > 0$
# - $ l = 2$
# - $m_l = -2, \ -1, \ 0, \ 1, \ 2$
#
# - Angular part $Y(\theta, \phi)$
#
#     - $Y_{d_{z^2}} = (\frac{5}{16\pi})^{\frac{1}{2}}(3\cos^2\theta-1)$
#
#     - $Y_{d_{xz}} = (\frac{15}{4\pi})^{\frac{1}{2}}\sin\theta\cos\theta\cos\phi$
#
#     - $Y_{d_{yz}} = (\frac{15}{4\pi})^{\frac{1}{2}}\sin\theta\cos\theta\sin\phi$
#
#     - $Y_{d_{xy}} = (\frac{15}{16\pi})^{\frac{1}{2}}\sin^2\theta\sin2\phi$
#
#     - $Y_{d_{x^{2}-y^{2}}} = (\frac{15}{16\pi})^{\frac{1}{2}}\sin^2\theta\cos2\phi$
#
#
#
#
# - Radial Part $R_{nl}(r)$
#
#     - $R_{3d} = \frac{4}{81\sqrt{30}}(\frac{Z}{a_0})^{\frac{3}{2}}\sigma^{2}\mathrm{e}^{\frac{-\sigma}{3}}$

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

#def bohr radius
a = 0.529*10**(-10)

#def x,y,z,r, theta, phi
x = np.linspace(-20*a, 20*a, 800)
y = np.linspace(-20*a, 20*a, 800)
z = np.linspace(-20*a, 20*a, 800)

x2,y2 = np.meshgrid(x,y)
z2,y3 = np.meshgrid(z,y)

r = np.sqrt(x2*x2+y2*y2)
r2 = np.sqrt(z2*z2+y3*y3)

t = np.arccos(z2/r2)

p = np.arctan2(y2,x2)

#def sigma
s = r/a
s2 = r2/a

#def angular part
ydz = np.sqrt(5/(16*np.pi))*(3*(np.cos(t))**2-1)
ydxz = np.sqrt(15/(4*np.pi))*np.sin(t)*np.cos(t)*np.cos(p)
ydyz = np.sqrt(15/(4*np.pi))*np.sin(t)*np.cos(t)*np.sin(p)
ydxz = np.sqrt(15/(16*np.pi))*np.sin(t)**2*np.sin(2*p)
ydx2y2 = np.sqrt(15/(4*np.pi))*np.sin(t)**2*np.cos(2*p)

#def radial part
r3d = 4/(81*np.sqrt(30))*(1/a)**(1.5)*s**2*np.exp(-s/3)
r3d2 = 4/(81*np.sqrt(30))*(1/a)**(1.5)*s2**2*np.exp(-s2/3)

#wavefunction
psi1 = (ydz*r3d2)**2
psi2 = (ydxz*r3d)**2
psi3 = (ydyz*r3d)**2
psi4 = (ydxz*r3d)**2
psi5 = (ydx2y2*r3d2)**2

#plot things
fig = plt.figure()
fig_size = plt.rcParams["figure.figsize"]
plt.suptitle("Contour maps on xy plane")
ax1 = fig.add_subplot(231)
ax2 = fig.add_subplot(232)
ax3 = fig.add_subplot(233)
ax4 = fig.add_subplot(234)
ax5 = fig.add_subplot(236)

ax1.contour(y3,z2,psi1, 30)
ax1.title.set_text("$3d_{z^2} \ \psi$ on yz plane")


ax2.contour(x2,y2,psi2, 30)
ax2.title.set_text("$3d_{xz} \ \mid \psi \mid^2$ on xy plane ")


ax3.contour(y3,z2,psi5, 30)
ax3.title.set_text("$3d_{yz} \ \mid \psi \mid^2$ on yz plane")


ax4.contour(x2,y2,psi4, 30)
ax4.title.set_text("$3d_{xy} \ \mid \psi \mid^2$ on xy plane")


ax5.contour(x2,y2,psi3, 30)
ax5.title.set_text("$3d_{x^2-y^2} \ \mid \psi \mid^2$ on xy plane")

fig_size[0] = 15
fig_size[1] = 10


plt.show()

# %% [markdown]
# #### Other nuclear interactions ####
#
# ##### shielding effects
# - inner electron shield outer electron from full charge Z of the nucleus
#     - reduces nuclear charge electron actually experiences
#     - makes the electron easier to remove
# - electrons at the same sublevel repel each other
#     - less energy to remove
#     - lower effective nuclear charge
#
# ##### Penetration effects
# - effect of orbital shape, $l$, on sublevel energy depends on penetration of radial probability distribuition curves
#     - e.g the 2s sublevel is lower in energy than the 2p orbital because it penetrates closer to the nucleus
#
# ##### Effects on sublevel energy -basically stuff learned before
# - Splitting of energy level into different energy levels
# - Removed degeneracy of energy levels for H atom states with different $l$ values
# - in general sublevel energy increases as $n \ (1<2<3<4)$ increases and as $l \ (s<p<d<f)$ increases
# - as $n$ increases some sublevels overlap
# - sublevels are filled from low to high energy

# %% [markdown]
# ## <span style="color:#879cc1">Electronic transitions</span> <a name="3"></a>
#
#
# [go to top](#top)

# %% [markdown]
# - an electron can only have certain energy values, called energy levels
# - at $n=1$ the atom is in it lowest energy state(ground state)
#
# #### Energy level postulates
#
# - an electron can change energy levels by
#     - absorbing energy to move to a higher energy level
#         - when the electron is higher than $n=1$ it is excited
#     - emitting energy to move to a lower energy level
#
#
# - energy of the photon is the difference between the energies of the 2 energy
# states
#
# $$\mid \Delta E\mid = \mid E_{final} - E_{initial}\mid = h\nu$$
#
# #### Energy of electron
#
# ##### Single electron system
#
#
# $$E_n \ = \ \frac{-Z^2 \mathrm{e}^4 m_e}{8\epsilon_0 n^2 h^2} \ = \ -(2.18\times 10^{-18} \mathrm{J})\frac{Z^2}{n^2}$$
#
#
# ##### Many electron system
#
# $$E_n \ = \ \frac{-Z_{eff}^2 \mathrm{e}^4 m_e}{8\epsilon_0 n^2 h^2} \ = \ -(2.18\times 10^{-18} \mathrm{J})\frac{Z_{eff}^2}{n^2}$$
#
#
# #### Rydberg Equation
#
# - predict position and wavelength of any atomic spectra line in a given series
#
# $$\mathrm{wavenumber, \ }k = \frac{1}{\lambda} = R\left( \frac{1}{n_1^2}-\frac{1}{n_2^2}\right)$$
#
# where R is the Rydberg constant $=1.0968\times 10^7 \ m^{-1}$

# %% [markdown]
# ## <span style="color:#879cc1">Photoelectron Spectroscopy</span> <a name="4"></a>
#
#
# [go to top](#top)

# %% [markdown]
# #### Removing electrons
#
#
# - photon spectroscopy used to determine the binding energies of the electrons in atoms/ions
#
# - photon strikes atom with sufficient energy to eject electrons from both the valence and core shells
#     - energy supplied is constant, what is measured is the KE of the ejected electron
#     - Can be removed from any of the occupied electronic orbitals
#
# #### Ionisation energy
#
# $$\mid E_{in} \mid = \mid IE \mid + \mid KE \mid$$
#
#
# - 1s electron
#     - majority of energy used to ionise atom
#     - small amount of energy converted to kinetic energy for ejected electron
#
# - 2p electron
#     - low ionisation energy
#     - ejected electron has high kinetic energy
#
# - energy required to form an ion with an electron from **any of the occupied atomic orbitals** is called the ionisation energy of the orbital $\mathrm{IE}_{nl}$
#
# $$\mathrm{IE}_{nl} = E_{ \infty } - E_{n} = -E_n$$
#
#
# $$\mathrm{BE}_{nl} = E_{n} - E_{\infty} = E_n$$
#
# where $\mathrm{BE}_{nl}$ denotes the binding energy of the orbital

# %% [markdown]
# ## <span style="color:#879cc1">Molecular Orbital Theory</span> <a name="5"></a>
#
#
# [go to top](#top)

# %% [markdown]
# #### Overview
#
# ![alt text](http://chemed.chem.purdue.edu/genchem/topicreview/bp/ch8/graphics/fig8_31.gif)
#
# - Consists of
#     - energy axis
#     - atomic orbitals(1s,2s,2p, etc)
#     - molecular orbitals
#     - electrons of molecule
#
#  - Uses Linear Combination of Atomic Orbitals approxmation (LCAO)
#  - Qualitatively describes bonding in molecules
#
# #### How to:
#
#  <span style="color:red">**Refer to slides Week 3 L2**</span>(Sorry but i dont know how to summarise it into a readable form)
#
#
# #### Orbitals
#
# - Bonding MO - constructive interference of wavefunctions
# - Antibonding MO - destructive interference of wavefunctions
#
# - If Z $\ge 8$, energies of s and p AOs are different and do not interact, ie $\pi_{2p} > \sigma_{2p}$
#
# - If Z $\le 8$, atoms are relatively large so orbital energies for 2s and 2p are close and they interact
#     - energies of $\sigma_{2s}$ and $\sigma_{2s}^*$ are lowered
#     - energies of $\pi_{2s}$ and $\pi_{2s}^*$ are increased
#
#     - $\pi_{2p} < \sigma_{2p} < \pi_{2p}^* < \sigma_{2p}^*$
#
# HOMO is the orbital that acts as an electron donor and LUMO is the orbital that acts as an electron acceptor
#
#
# #### MO bond order
#
# - Bond order  = $\frac{1}{2}$[(# of electron in bonding MO) -(# of antibonding electron)]
#
#     - Bond order > 0 $\Rightarrow$ molecule is more stable than separate atoms so it forms
# <br/><br/>
#     - Bond order < 0 $\Rightarrow$ molecule is as stable as separate atoms so it will not form
#
#
# - the higher the bond order the shorter and stronger the bond
#
# #### Para/Diamagnetism
#
# - electron spin generates a tiny magnetic field
# <br/>
# <br/>
# - a species with one or more unpaired electrons will be affected by a external field (paramagnetism)
# <br/>
# <br/>
# - a species with no unpaired electron will be unaffected by an external field as the fields of the paired electrons cancel each other (Diamagnetism)

# %% [markdown]
# ## <span style="color:#879cc1">Band Theory</span> <a name="6"></a>
#
#
# [go to top](#top)

# %% [markdown]
# - when many atoms interact, many closely spaced discrete energy levels form energy bands
#
#
# #### Insulator
#
# - Band gap > 3 eV
# - large energy gap between valence and conducion bands
# - no current observed when the insulator is heated
#
# #### Conductors
# - Band gap = 0
# - Highest energy valence electrons are easily excited into empty conduction orbitals
# - electrons in the conduction orbitals can move freely throughout the sample
# - as temperature increases, atoms random motion hinders electron movement $\rightarrow$ conductivity decreases
#
# #### Semiconductors
#
# - Band gap < 3 eV for intrinsic semiconductors
#     - electrons = holes
#
# - Extrinsic semiconductors are doped with small quantities of impurities
#
# - n-type: electrons > holes
# - p-type: holes > electons
#
# - electrons can be thermally excited to cross from valence to conduction band
# - as temperature increases, more electrons can be excited $\rightarrow$ net increase in conductivity
#
# - relationship between carrier concentration and temperature resembles the Boltzmann distribution
#
# - at 0 K, valence band completely filled and separated from conduction band by narrow band gap
#
# #### Doping
#
# - n type:
#     - the state of the $5^{th}$ electron in the donor atoms are located very close to the conduction band
#     - at r.t.p we can assume all the donor atoms get ionised and form free electrons by gaining thermal energy
#     - free electrons are formed without hole creation
#
#
# - p type:
#     - acceptor atoms introduce states very close to the valence band
#     - ionisation into these states results in holes in the valence band
#     - electrons that move into these isolated states are bound to the acceptor sites and not free to conduct electricity
#
#
# - Doping concentration
#     - $N_d$ is the doping concentration for n-type (donor)
#     - $N_a$ is the doping concentration for p-type (acceptor)
#
#     - intrinsic carrier concentration $n_i^2 = n \times p$ (Law of mass action)
#
# #### Conductivity
# $$\sigma = q(n\mu_e+p\mu_h)$$
#
# q: electron charge
# n: free electron concentration
# p: hole concentration
#
# $\mu_e$: electron mobility
#
# $\mu_h$: hole mobility
#
# - For intrinsic semiconductors, $n = p = n_i$
# - recombination of electons and holes causes electron to lose its energy in the form of light or thermal energy

# %% [markdown]
# ## <span style="color:#879cc1">Transition Elements</span> <a name="7"></a>
#
#
# [go to top](#top)

# %% [markdown]
# #### Properties
#
# #### Ligands
#
# ##### Lewis Acid/Bases
# - Lewis base is a species that donates lone-pair electrons
# - Lewis acid is a species that accepts lone-pair electrons
#
# ##### Ligands
#
# - Ligands are lewis bases
# - Ligands of a complex ions are molecules/anions with one or more donor atoms
#     - A complex forms between a metal and ligand
#     - electrons in the bond originate from the ligand
# - Monodentate
#     - ligands donate 2 electrons and form 1 bond
# - Bidentate
#     - ligands donate 4 electrons and form 2 bonds
# - Chelator
#     - ligand that forms more than one bond to the metal
# - Metal Chelator
#     - ligand that sequesters away the metal
#
# Coordination number(CN): # of atoms bonded directly to central atom
# - CN = 2:
#     - linear
# - CN = 3:
#     - trigonal planar/pyramidal
# - CN = 4:
#     - Square planar/tetrahedral
# - CN = 5:
#     - trigonal bipyramidal/square pyramidal
# - CN = 6:
#     - octahedral/trigonal prism
# - CN = 7:
#     - pentagonal bipyramidal
